# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Neeraj\Downloads\Student_Performance.csv")

# %%
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
df.isnull().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
#        'Sleep Hours', 'Sample Question Papers Practiced', 'Performance Index'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb = LabelEncoder()

# %%
df["Hours Studied"]=lb.fit_transform(df["Hours Studied"])
df["Previous Scores"]=lb.fit_transform(df["Previous Scores"])
df["Extracurricular Activities"] = lb.fit_transform(df["Extracurricular Activities"])
df["Sleep Hours	"]=lb.fit_transform(df["Sleep Hours"])
df["Sample Question Papers Practiced"]=lb.fit_transform(df["Sample Question Papers Practiced"])

# %%
df
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0                 6               59                           1            9
# 1                 3               42                           0            4
# 2                 7               11                           1            7
# 3                 4               12                           1            5
# 4                 6               35                           0            8
# ...             ...              ...                         ...          ...
# 9995              0                9                           1            4
# 9996              6               24                           1            8
# 9997              5               43                           1            8
# 9998              8               57                           1            7
# 9999              6               34                           0            8
#
# ...

# %%
y = df["Performance Index"]
X = df

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_test,y_test)
# Out:
# 1.0

# %%
from sklearn.model_selection import cross_val_score

# %%
cross_val_score(lr,X,y,cv=5)
# Out:
# array([1., 1., 1., 1., 1.])

# %%
import pickle
with open('model.pickle','wb') as model_file:
    pickle.dump(lr,model_file)
